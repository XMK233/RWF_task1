# %%
# import sys, os
# os.chdir(os.getcwd())

# %%
from x__params import *
# from x__hive import *
# Out:
# storage dir: /Users/minkexiu/Downloads/GitHub/RWF_task1/data/2025Q3/20250727_股票和基金/2-get_feature
# code dir: /Users/minkexiu/Documents/GitHub/RWF_task1/code/2025Q3/20250727_股票和基金/2-get_feature
# 27 18 14
# 先天八卦数: 1乾, 2兑, 3离, 4震, 5巽, 6坎, 7艮, 8坤
# 本卦上：3 本卦下：2 变爻：2
#     火泽睽 水火既济 火雷噬嗑
# 上卦  ☲离火  ☵坎水  ☲离火
# 下卦  ☱兑金  ☲离火  ☳震木
# 06 03 10 酉时
# 先天八卦数: 1乾, 2兑, 3离, 4震, 5巽, 6坎, 7艮, 8坤
# 本卦上：6 本卦下：3 变爻：4
#    水火既济 火水未济  泽火革
# 上卦  ☵坎水  ☲离火  ☱兑金
# 下卦  ☲离火  ☵坎水  ☲离火

# %%
## 这里要选择一下。
sample_scheme = "600519_to20250725"
scheme_type = "extra_fea_1"

# %% [markdown]
# # 设计一下吧
#
# 我们应该考虑一些额外的特征，比如当时的经济形势状况啊，国际格局啊，政策啊，新闻啊之类的。
#
# 尝试把我们平时看的新闻，落到实处吧。
#
# * 经济形势：
#     * 宏观的，比如说政策啊之类的。
#     * 微观的，比如说什么汇率啊准备金率啊之类的东西。
# * 社会、国际新闻：
#     * 国内各省？
#     * 网上热点？
#     * 美国？欧洲？日本？中东？拉美、非洲、东南亚、印度？
# * 。。。

# %% [raw]
# Prompt示例：
# "请分析[日期]期间的市场环境特征：
# 1. 该时期主要的市场事件和政策
# 2. 市场情绪指标（乐观/悲观/震荡）
# 3. 流动性环境（宽松/紧缩）
# 4. 主要指数表现特征
# 5. 季节性因素影响
# 输出为数值化特征。"
