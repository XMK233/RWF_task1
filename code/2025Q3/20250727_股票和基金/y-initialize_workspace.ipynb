# %%
import os

# %%
## 初步建立一些简单的目录结构：
for dirname in [
    "1-sample",
    "2-get_feature",
    "3-data_preprocess",
    "4-build_model"
]:
    os.makedirs(
        os.path.join(dirname, "wasted/")
    )
